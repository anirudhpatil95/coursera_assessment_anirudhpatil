# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anirudh Patil** <br>
# I currnetly work as a Senior Business Analyst.

# %% [markdown]
# *I am interested in Data Science because I feel problems of the coming decade would circle around and would be solvable with Data. The demand for it grows by the4 second and hence, in this data revolution, I would like to contribute my part*

# %% [markdown]
# ### The Code below takes an input name and prints welcome message for the user

# %%
name = "Please Enter Your Name"
a = input(name)
print ("Watson welcomes you" + a)

# %% [markdown]
# ---
# This paragrapgh is for the final task mentioned in the assignment. To exhibit, I'm using the following three :
#
# <ul>
#     <li>Horizontal Rule</li>
#     <li>Bulleted List</li>
#     <li>Numbered List</li>
# </ul>
#
# To use a numbered list, I'll simply print the six Infinity Stones to keep the inner nerd alive!
#
# <ol>
#     <li>Tesseract</li>
#     <li>Aether</li>
#     <li>The Orb</li>
#     <li>Mind Stone</li>
#     <li>Soul Stone</li>
#     <li>Eye of Agamotto</li>
# </ol>
#
# I could also add the hyperlink for the Wikipedia page of <a href= "https://en.wikipedia.org/wiki/Christopher_Nolan"> Christopher Nolan</a>, my favorite director.
